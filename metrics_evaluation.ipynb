# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

# %%
file_path = './target/evaluation.csv'
data = pd.read_csv(file_path)
data.head()

lburst_path = './uc10_lburst_metrics'
sburst_path = './uc10_sburst_metrics'
linterval_path = './uc10_individual_long_interval_metrics'
minterval_path = './uc10_individual_moderate_interval_metrics'
sinterval_path = './uc10_individual_short_interval_metrics'

dual_attack_sinterval_path = './uc10_dual_attack_short_interval_metrics/uc01uc10_metrics'

# create these directories if they do not exist
#import os
#os.makedirs(lburst_path, exist_ok=True)
#os.makedirs(sburst_path, exist_ok=True)
#os.makedirs(linterval_path, exist_ok=True)
#os.makedirs(minterval_path, exist_ok=True)
#os.makedirs(sinterval_path, exist_ok=True)
#os.makedirs(dual_attack_sinterval_path, exist_ok=True)

# %%
if (data[data['Model'] == 'J48']['Accuracy'].mean() == data[data['Model'] == 'RandomForest']['Accuracy'].mean() and (data[data['Model'] == 'J48']['F1 Score'].mean() == data[data['Model'] == 'RandomForest']['F1 Score'].mean()) and (data[data['Model'] == 'J48']['Precision'].mean() == data[data['Model'] == 'RandomForest']['Precision'].mean())):
    print("Equal results Random Forest and J48")

if (data[data['Model'] == 'J48']['Accuracy'].mean() == data[data['Model'] == 'NaiveBayes']['Accuracy'].mean() and (data[data['Model'] == 'J48']['F1 Score'].mean() == data[data['Model'] == 'NaiveBayes']['F1 Score'].mean()) and (data[data['Model'] == 'J48']['Precision'].mean() == data[data['Model'] == 'NaiveBayes']['Precision'].mean())):
    print("Equal results Naive Bayes and J48")

if (data[data['Model'] == 'J48']['Accuracy'].mean() == data[data['Model'] == 'REPTree']['Accuracy'].mean() and (data[data['Model'] == 'J48']['F1 Score'].mean() == data[data['Model'] == 'REPTree']['F1 Score'].mean()) and (data[data['Model'] == 'J48']['Precision'].mean() == data[data['Model'] == 'REPTree']['Precision'].mean())):
    print("Equal results REPTree and J48")
# Out:
# Equal results Random Forest and J48
# Equal results Naive Bayes and J48
# Equal results REPTree and J48

# %% [markdown]
# # Mean and Median of metrics for each model

# %%
print('J48 model metrics evaluation:\n')
print('Accuracy Mean: ', data[data['Model'] == 'J48']['Accuracy'].mean()) 
print('Accuracy Median: ', data[data['Model'] == 'J48']['Accuracy'].median())

print('Precision Mean: ', data[data['Model'] == 'J48']['Precision'].mean()) 
print('Precision Median: ', data[data['Model'] == 'J48']['Precision'].median())

print('Recall Mean: ', data[data['Model'] == 'J48']['Recall'].mean()) 
print('Recall Median: ', data[data['Model'] == 'J48']['Recall'].median())

print('F1-Score Mean: ', data[data['Model'] == 'J48']['F1 Score'].mean()) 
print('F1-Score Median: ', data[data['Model'] == 'J48']['F1 Score'].median())

print('True Pos Mean: ', data[data['Model'] == 'J48']['True Pos'].mean()) 
print('True Pos Median: ', data[data['Model'] == 'J48']['True Pos'].median())

print('True Neg Mean: ', data[data['Model'] == 'J48']['True Neg'].mean()) 
print('True Neg Median: ', data[data['Model'] == 'J48']['True Neg'].median())

print('False Pos Mean: ', data[data['Model'] == 'J48']['False Pos'].mean()) 
print('False Pos Median: ', data[data['Model'] == 'J48']['False Pos'].median())

print('False Neg Mean: ', data[data['Model'] == 'J48']['False Neg'].mean()) 
print('False Neg Median: ', data[data['Model'] == 'J48']['False Neg'].median())
# Out:
# J48 model metrics evaluation:
#
# Accuracy Mean:  0.9964210699999999
# Accuracy Median:  0.99636725
# Precision Mean:  0.8940380841493607
# Precision Median:  0.8912405371665955
# Recall Mean:  0.9993176460266113
# Recall Median:  1.0
# F1-Score Mean:  0.94346267
# F1-Score Median:  0.9424927999999999
# True Pos Mean:  3500.85
# True Pos Median:  2881.0
# True Neg Mean:  99633.1
# True Neg Median:  99627.0
# False Pos Mean:  365.9
# False Pos Median:  372.0
# False Neg Mean:  4.75
# False Neg Median:  0.0

# %%
print('RandomForest model metrics evaluation:\n')
print('Accuracy Mean: ', data[data['Model'] == 'RandomForest']['Accuracy'].mean()) 
print('Accuracy Median: ', data[data['Model'] == 'RandomForest']['Accuracy'].median())

print('Precision Mean: ', data[data['Model'] == 'RandomForest']['Precision'].mean()) 
print('Precision Median: ', data[data['Model'] == 'RandomForest']['Precision'].median())

print('Recall Mean: ', data[data['Model'] == 'RandomForest']['Recall'].mean()) 
print('Recall Median: ', data[data['Model'] == 'RandomForest']['Recall'].median())

print('F1-Score Mean: ', data[data['Model'] == 'RandomForest']['F1 Score'].mean()) 
print('F1-Score Median: ', data[data['Model'] == 'RandomForest']['F1 Score'].median())

print('True Pos Mean: ', data[data['Model'] == 'RandomForest']['True Pos'].mean()) 
print('True Pos Median: ', data[data['Model'] == 'RandomForest']['True Pos'].median())

print('True Neg Mean: ', data[data['Model'] == 'RandomForest']['True Neg'].mean()) 
print('True Neg Median: ', data[data['Model'] == 'RandomForest']['True Neg'].median())

print('False Pos Mean: ', data[data['Model'] == 'RandomForest']['False Pos'].mean()) 
print('False Pos Median: ', data[data['Model'] == 'RandomForest']['False Pos'].median())

print('False Neg Mean: ', data[data['Model'] == 'RandomForest']['False Neg'].mean()) 
print('False Neg Median: ', data[data['Model'] == 'RandomForest']['False Neg'].median())
# Out:
# RandomForest model metrics evaluation:
#
# Accuracy Mean:  0.9964210699999999
# Accuracy Median:  0.99636725
# Precision Mean:  0.8940380841493607
# Precision Median:  0.8912405371665955
# Recall Mean:  0.9993176460266113
# Recall Median:  1.0
# F1-Score Mean:  0.94346267
# F1-Score Median:  0.9424927999999999
# True Pos Mean:  3500.85
# True Pos Median:  2881.0
# True Neg Mean:  99633.1
# True Neg Median:  99627.0
# False Pos Mean:  365.9
# False Pos Median:  372.0
# False Neg Mean:  4.75
# False Neg Median:  0.0

# %%
print('NaiveBayes model metrics evaluation:\n')
print('Accuracy Mean: ', data[data['Model'] == 'NaiveBayes']['Accuracy'].mean()) 
print('Accuracy Median: ', data[data['Model'] == 'NaiveBayes']['Accuracy'].median())

print('Precision Mean: ', data[data['Model'] == 'NaiveBayes']['Precision'].mean()) 
print('Precision Median: ', data[data['Model'] == 'NaiveBayes']['Precision'].median())

print('Recall Mean: ', data[data['Model'] == 'NaiveBayes']['Recall'].mean()) 
print('Recall Median: ', data[data['Model'] == 'NaiveBayes']['Recall'].median())

print('F1-Score Mean: ', data[data['Model'] == 'NaiveBayes']['F1 Score'].mean()) 
print('F1-Score Median: ', data[data['Model'] == 'NaiveBayes']['F1 Score'].median())

print('True Pos Mean: ', data[data['Model'] == 'NaiveBayes']['True Pos'].mean()) 
print('True Pos Median: ', data[data['Model'] == 'NaiveBayes']['True Pos'].median())

print('True Neg Mean: ', data[data['Model'] == 'NaiveBayes']['True Neg'].mean()) 
print('True Neg Median: ', data[data['Model'] == 'NaiveBayes']['True Neg'].median())

print('False Pos Mean: ', data[data['Model'] == 'NaiveBayes']['False Pos'].mean()) 
print('False Pos Median: ', data[data['Model'] == 'NaiveBayes']['False Pos'].median())

print('False Neg Mean: ', data[data['Model'] == 'NaiveBayes']['False Neg'].mean()) 
print('False Neg Median: ', data[data['Model'] == 'NaiveBayes']['False Neg'].median())
# Out:
# NaiveBayes model metrics evaluation:
#
# Accuracy Mean:  0.9964210699999999
# Accuracy Median:  0.99636725
# Precision Mean:  0.8940380841493607
# Precision Median:  0.8912405371665955
# Recall Mean:  0.9993176460266113
# Recall Median:  1.0
# F1-Score Mean:  0.94346267
# F1-Score Median:  0.9424927999999999
# True Pos Mean:  3500.85
# True Pos Median:  2881.0
# True Neg Mean:  99633.1
# True Neg Median:  99627.0
# False Pos Mean:  365.9
# False Pos Median:  372.0
# False Neg Mean:  4.75
# False Neg Median:  0.0

# %%
print('REPTree model metrics evaluation:\n')
print('Accuracy Mean: ', data[data['Model'] == 'REPTree']['Accuracy'].mean()) 
print('Accuracy Median: ', data[data['Model'] == 'REPTree']['Accuracy'].median())

print('Precision Mean: ', data[data['Model'] == 'REPTree']['Precision'].mean()) 
print('Precision Median: ', data[data['Model'] == 'REPTree']['Precision'].median())

print('Recall Mean: ', data[data['Model'] == 'REPTree']['Recall'].mean()) 
print('Recall Median: ', data[data['Model'] == 'REPTree']['Recall'].median())

print('F1-Score Mean: ', data[data['Model'] == 'REPTree']['F1 Score'].mean()) 
print('F1-Score Median: ', data[data['Model'] == 'REPTree']['F1 Score'].median())

print('True Pos Mean: ', data[data['Model'] == 'REPTree']['True Pos'].mean()) 
print('True Pos Median: ', data[data['Model'] == 'REPTree']['True Pos'].median())

print('True Neg Mean: ', data[data['Model'] == 'REPTree']['True Neg'].mean()) 
print('True Neg Median: ', data[data['Model'] == 'REPTree']['True Neg'].median())

print('False Pos Mean: ', data[data['Model'] == 'REPTree']['False Pos'].mean()) 
print('False Pos Median: ', data[data['Model'] == 'REPTree']['False Pos'].median())

print('False Neg Mean: ', data[data['Model'] == 'REPTree']['False Neg'].mean()) 
print('False Neg Median: ', data[data['Model'] == 'REPTree']['False Neg'].median())
# Out:
# REPTree model metrics evaluation:
#
# Accuracy Mean:  0.9964210699999999
# Accuracy Median:  0.99636725
# Precision Mean:  0.8940380841493607
# Precision Median:  0.8912405371665955
# Recall Mean:  0.9993176460266113
# Recall Median:  1.0
# F1-Score Mean:  0.94346267
# F1-Score Median:  0.9424927999999999
# True Pos Mean:  3500.85
# True Pos Median:  2881.0
# True Neg Mean:  99633.1
# True Neg Median:  99627.0
# False Pos Mean:  365.9
# False Pos Median:  372.0
# False Neg Mean:  4.75
# False Neg Median:  0.0

# %%
# put these statistics for each model in a pdf document bursts: vsmall interval is 3-15, small is 15 - 25, medium is 25-50, large is 50-100
# individual messages: small interval is 5 - 25, moderate is 25 - 50, large is 50 - 100
models = ['J48', 'RandomForest', 'NaiveBayes', 'REPTree']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'True Pos', 'True Neg', 'False Pos', 'False Neg']
stats = ['Mean', 'Median', 'Min', 'Max', 'Std']
with open(sinterval_path + '/low_prob_400_100/model_metrics_evaluation_400_100.txt', 'w') as f:
    for model in models:
        f.write(f'Model: {model}\n')
        for metric in metrics:
            f.write(f'  Metric: {metric}\n')
            f.write(f'    Mean: {data[data["Model"] == model][metric].mean()}\n')
            f.write(f'    Median: {data[data["Model"] == model][metric].median()}\n')
            f.write(f'    Min: {data[data["Model"] == model][metric].min()}\n')
            f.write(f'    Max: {data[data["Model"] == model][metric].max()}\n')
            f.write(f'    Std: {data[data["Model"] == model][metric].std()}\n')
        f.write('\n')

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'True Pos', 'True Neg', 'False Pos', 'False Neg']

# open a directory to save the plots

for metric in metrics:
    plt.figure()
    data.boxplot(column=metric, by='Model')
    plt.title(f'Box and Whisker Plot for {metric}')
    plt.suptitle('')
    plt.xlabel('Model')
    plt.ylabel(metric)
    plt.savefig(sinterval_path + '/low_prob_400_100' + f'/{metric.lower().replace(" ", "_")}_boxplot_400_100.pdf')
    plt.close()

# %% [markdown]
# # MAX and MIN of metrics for each model

# %%
print('\nJ48 model metrics min and max values:\n')
for col in data[data['Model'] == 'J48'].columns[1:]:
    print(col + ' Min: ', data[data['Model'] == 'J48'][col].min())
    print(col + ' Max: ', data[data['Model'] == 'J48'][col].max())
# Out:
# J48 model metrics min and max values:
#
# Accuracy Min:  0.9141515
# Accuracy Max:  0.9394487
# Precision Min:  0.7832450270652771
# Precision Max:  0.8398849964141846
# Recall Min:  0.9196445941925048
# Recall Max:  0.976980209350586
# F1 Score Min:  0.8652868
# F1 Score Max:  0.889424
# True Pos Min:  13974
# True Pos Max:  21560
# True Neg Min:  44414
# True Neg Max:  47270
# False Pos Min:  2729
# False Pos Max:  5585
# False Neg Min:  508
# False Neg Max:  1221
# Eval Time Min:  1725
# Eval Time Max:  2047

# %%
print('\nRandomForest model metrics min and max values:\n')
for col in data[data['Model'] == 'RandomForest'].columns[1:]:
    print(col + ' Min: ', data[data['Model'] == 'RandomForest'][col].min())
    print(col + ' Max: ', data[data['Model'] == 'RandomForest'][col].max())
# Out:
# RandomForest model metrics min and max values:
#
# Accuracy Min:  0.9141515
# Accuracy Max:  0.9394487
# Precision Min:  0.7832450270652771
# Precision Max:  0.8398849964141846
# Recall Min:  0.9196445941925048
# Recall Max:  0.976980209350586
# F1 Score Min:  0.8652868
# F1 Score Max:  0.889424
# True Pos Min:  13974
# True Pos Max:  21560
# True Neg Min:  44414
# True Neg Max:  47270
# False Pos Min:  2729
# False Pos Max:  5585
# False Neg Min:  508
# False Neg Max:  1221
# Eval Time Min:  1594
# Eval Time Max:  1796

# %%
print('\nNaiveBayes model metrics min and max values:\n')
for col in data[data['Model'] == 'NaiveBayes'].columns[1:]:
    print(col + ' Min: ', data[data['Model'] == 'NaiveBayes'][col].min())
    print(col + ' Max: ', data[data['Model'] == 'NaiveBayes'][col].max())
# Out:
# NaiveBayes model metrics min and max values:
#
# Accuracy Min:  0.9141515
# Accuracy Max:  0.9394487
# Precision Min:  0.7832450270652771
# Precision Max:  0.8398849964141846
# Recall Min:  0.9196445941925048
# Recall Max:  0.976980209350586
# F1 Score Min:  0.8652868
# F1 Score Max:  0.889424
# True Pos Min:  13974
# True Pos Max:  21560
# True Neg Min:  44414
# True Neg Max:  47270
# False Pos Min:  2729
# False Pos Max:  5585
# False Neg Min:  508
# False Neg Max:  1221
# Eval Time Min:  1593
# Eval Time Max:  1799

# %%
print('\nREPTree model metrics min and max values:\n')
for col in data[data['Model'] == 'REPTree'].columns[1:]:
    print(col + ' Min: ', data[data['Model'] == 'REPTree'][col].min())
    print(col + ' Max: ', data[data['Model'] == 'REPTree'][col].max())
# Out:
# REPTree model metrics min and max values:
#
# Accuracy Min:  0.9141515
# Accuracy Max:  0.9394487
# Precision Min:  0.7832450270652771
# Precision Max:  0.8398849964141846
# Recall Min:  0.9196445941925048
# Recall Max:  0.976980209350586
# F1 Score Min:  0.8652868
# F1 Score Max:  0.889424
# True Pos Min:  13974
# True Pos Max:  21560
# True Neg Min:  44414
# True Neg Max:  47270
# False Pos Min:  2729
# False Pos Max:  5585
# False Neg Min:  508
# False Neg Max:  1221
# Eval Time Min:  1604
# Eval Time Max:  1857
